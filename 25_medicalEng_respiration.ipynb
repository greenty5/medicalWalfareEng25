# %% [markdown]
# # Medical Walfare Engineering, 2025
# by Takahisa Yamamoto
# ## Respiration
# ***

# %% [markdown]
# Hello! This is a quick intro to programming in Python to help you hit the ground running with _Medical Walfare Engineering with Python_.
#
# There are two ways to enjoy these lessons with Python:
#
# You can run Python in the cloud using _[Google Colaboratory](https://colab.research.google.com/)_, for which you need to create a free account. (No software installation required! (__strongly recommended on this course__)).
#
# You can download and install a Python distribution on your computer. One of options is the free _[Anaconda](https://www.anaconda.com/products/distribution)_ Scientific Python distribution.
#
#
# You will get a new browser window or tab with a list of the notebooks available in that folder. Click on one and start working!
#
# In this ipynb file, let us learn how to build python codes and how to use google colabratory.

# %% [markdown]
# First of all, we have to import python laibraries which are really important in this course.

# %% [markdown]
# <font color="orange"> Let us try to execute following code cell.</font>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You can calculate everything on this jupyterLab file (Google coraboratory) realy easily.

# %%
a = np.array([1,2,3])
b = np.array([3,4,5])

c = a + b
d = a - c

print("c = ", c)
print("d = ", d)
# Out:
# c =  [4 6 8]
# d =  [-3 -4 -5]

# %%
r = 3.0
Area = np.pi * r**2
print("Area ... {:.3f}".format(Area))

R = np.sqrt(Area/np.pi)
print("R ... {:.3f}".format(R))
# Out:
# Area ... 28.274
# R ... 3.000

# %% [markdown]
# ---

# %% [markdown]
# ## Practice
#
# Let us review last week contents, namely Bernoulli's theorem.

# %% [markdown]
# ![Bernoulli's principle](./BernoullisTheorem.png)

# %% [markdown]
# Now we want to determine the velocity $v_2$ at the section #2 as shown in the figure. Given $v_1$ is 5 m/s, $p_1$ is 110 kPa and $p_2$ is 100 kPa, assume that elevation between these two section does not change.

# %%
# calculate the velocity at the sention #2
rho = 1.23 # density of air
v1 = 5
p1 = 110e3
p2 = 100e3

# %% [markdown]
# ---

# %% [markdown]
# ![](https://i.imgur.com/imCm6Xm.png)
# ![](https://i.imgur.com/31Ukyvv.png)
# ![Tidal Volume](./ventilation.png)
# ![Tidal Volume](./tidalVolume.png)

# %% [markdown]
# <font color="orange">Let us estimate alveolar ventilation when tidal volume is 1200mL, breathing rate frequency is 7 and dead space of airway is 150mL.</font>

# %% [markdown]
# ![Dolton's law](./DoltonsLaw.png)

# %% [markdown]
# <font color="orange"> Please try to solve quizes mentioned above </font> 😀

# %% [markdown]
# ![MtEverest](./MtEverest.png)

# %% [markdown]
# <font color="red">Over to you!!</font>
#
# <font color="orange"> what is the partial pressure of inhaled oxygen at the top of Mt. Everest </font>

# %% [markdown]
# ![](https://i.imgur.com/SbifVrd.png)
# ![](https://i.imgur.com/3vo4hjn.png)
# ![](https://i.imgur.com/E8OcnRV.png)

# %% [markdown]
# <font color="red"> Over to you!! </font>
#
# <font color="orange"> partial pressure of oxygen in aorta is 13mmHg, and the altitude of the mountain we are here is about 8400m. Please determine the partial pressure of oxygen in alveoli </font>

# %% [markdown]
# ![](https://i.imgur.com/MFHtubl.png)

# %% [markdown]
# <font color="orange">In the case of mouth-to-mouth artificial respiration that rescuer’s partial pressure of carbon dioxide in alveoli is 40 mmHg,
# consider whether or not the person requiring rescue can be saved.</font>

# %% [markdown]
# ![](https://i.imgur.com/OXDf9ew.png)

# %% [markdown]
# <font color="orange"> A postoperative patient is in respiratory depression due to residual anesthesia. The patient’s partial pressure of carbon dioxide in aorta is 80 mmHg.
#
# Estimate two cases of partial pressures of oxygen in alveoli; one is the case with oxygenation (normal oxygen concentration), the other is with 40% enriched oxygenation. </font>

# %% [markdown]
# ---
#
# Job well done, everyone 😃
